# %% [markdown]
# # 📘 Python - Módulos e Pacotes
#
# ## 🎯 Objetivos
# - Criar e importar módulos
# - Entender pacotes e `__init__.py`
# - Explorar a biblioteca padrão (os, sys, math, datetime)
# - Gerenciar dependências com pip
#
# ## 📝 Conteúdo
#
# ### 1. Módulos
# - O que são módulos
# - Criar um módulo (arquivo `.py`)
# - Importar módulos (`import`, `from ... import`)
# - Módulos da biblioteca padrão
#
# ### 2. Pacotes
# - Estrutura de pacotes
# - O arquivo `__init__.py`
# - Importar de pacotes
#
# ### 3. Gerenciamento de Pacotes
# - `pip` (instalar, remover, listar)
# - Ambientes virtuais (`venv`)
# - `requirements.txt`
#
# ## ✅ Exercícios
# 1. Criar um módulo com funções úteis
# 2. Importar e usar o módulo
# 3. Instalar um pacote com pip
#
# ## 📚 Referências
# - [Documentação Python](https://docs.python.org/3/tutorial/modules.html)
