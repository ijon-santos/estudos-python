# %% [markdown]
# # 📘 Python - Funções e Escopo
#
# ## 🎯 Objetivos
# - Definir e chamar funções
# - Entender parâmetros e argumentos
# - Compreender escopo de variáveis (local, global)
# - Trabalhar com retorno de funções
#
# ## 📝 Conteúdo
#
# ### 1. Definindo Funções
# ```python
# def nome_funcao(param1, param2):
#     # corpo da função
#     return resultado
# ```
#
# ### 2. Parâmetros e Argumentos
# - Parâmetros posicionais
# - Parâmetros nomeados (keyword arguments)
# - Valores padrão
# - `*args` e `**kwargs`
#
# ### 3. Escopo de Variáveis
# - Variáveis locais (dentro da função)
# - Variáveis globais (fora da função)
# - A palavra-chave `global`
#
# ### 4. Funções com Retorno
# - `return`
# - Múltiplos valores
# - Funções sem retorno (`None`)
#
# ## ✅ Exercícios
# 1. Função que recebe dois números e retorna a soma
# 2. Função com valores padrão
# 3. Função com `*args`
#
# ## 📚 Referências
# - [Documentação Python](https://docs.python.org/3/tutorial/controlflow.html#defining-functions)
